# %%
import pandas as pd
df = pd.read_csv(r'../input/forbes-worlds-billionaires-list-2022/forbes_2022_billionaires.csv')
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
# ...

# %%
df.tail(5)
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state  ... organization  \
# 2663  Manufacturing               Fiberglass   China   NaN  ...          NaN
# 2664     Technology               Navigation   China   NaN  ...          NaN
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# ...

# %%
df.hist(bins = 10, figsize = (10,10))
# Out:
# array([[<AxesSubplot:title={'center':'rank'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'finalWorth'}>],
#        [<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'philanthropyScore'}>],
#        [<AxesSubplot:title={'center':'numberOfSiblings'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
for i in df.columns:
    print("Column " + i + " Unique Values: " + str(df[i].unique().size))
# Out:
# Column rank Unique Values: 228
# Column personName Unique Values: 2666
# Column age Unique Values: 77
# Column finalWorth Unique Values: 228
# Column year Unique Values: 1
# Column month Unique Values: 1
# Column category Unique Values: 18
# Column source Unique Values: 914
# Column country Unique Values: 74
# Column state Unique Values: 43
# Column city Unique Values: 750
# Column countryOfCitizenship Unique Values: 75
# Column organization Unique Values: 317
# Column selfMade Unique Values: 2
# Column gender Unique Values: 3
# Column birthDate Unique Values: 2045
# Column title Unique Values: 95
# Column philanthropyScore Unique Values: 6
# Column residenceMsa Unique Values: 110
# Column numberOfSiblings Unique Values: 11
# Column bio Unique Values: 2668
# Column about Unique Values: 1549

# %%
import seaborn as sns
import matplotlib.pyplot as plt
column_names = ["selfMade", "gender", "philanthropyScore", "numberOfSiblings", "category"]
for i in column_names:
    plt.figure()
    plt.title('Count Plot of Column ' + str(i))
    sns.countplot(y = i, data = df)
    plt.figure()
    plt.title('Average Net Worth')
    if i == 'category':
        sns.barplot(y = i, x = "finalWorth", data = df)
    else:
        sns.barplot(x = i, y = "finalWorth", data = df)

# %%
large_column_names = ["source", "country", "state", "city", "countryOfCitizenship", "organization", "title",
                     "residenceMsa"]
n = 20
for i in large_column_names:
    top_n = df[i].value_counts()[:n].index.tolist()
    top_n_df = df[df[i].isin(top_n)]
    plt.figure()
    plt.title('Count Plot for Top ' + str(n) + ' Most Common Occurences in Column ' + str(i))
    sns.countplot(y = i, data = top_n_df)
    plt.figure()
    plt.title('Net Worth')
    sns.barplot(y = i, x = "finalWorth", data = top_n_df)
